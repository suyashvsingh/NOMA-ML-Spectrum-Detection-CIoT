# %% [markdown]
# # $Rayleigh$

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.signal as ss
from matplotlib import pyplot as plt
from scipy.interpolate import interp1d
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Fixed parameters

# %%
# Constants
num_iter = 10000  # Number of Monte Carlo iterations
N = 2  # No of NOMA users
S = 4096  # Sampled length
a1, a2 = 0.8, 0.2  # Power allocations
Pf = 0.1  # False-alarm probability
env_SNRs_dB = np.arange(
    -25, 6, 1
)  # Range of environmental SNR values to iterate through
transmitter_power = 1
τ_T = 0.01  # Ratio of sensing time to total time
Throughputs_without_LR = []
Throughputs_with_LR = []

# %% [markdown]
# ### Lists to store results

# %%
Pds = []  # List to store detection probabilities
TPRs = []  # List to store true positive rates
Throughputs_without_LR = []  # List to store throughputs
Throughputs_with_LR = []  # List to store throughputs

# %% [markdown]
# ### Monte Carlo simulation

# %%
for env_SNR_dB in env_SNRs_dB:
    # Convert SNR from dB to linear scale
    env_SNR_linear = transmitter_power * 10 ** (env_SNR_dB / 10)

    # Noise standard deviation based on environmental SNR
    N0 = np.sqrt(1 / (2 * env_SNR_linear))

    # Threshold for AND joint user decision
    lambda_AND = (np.sqrt(-np.log(Pf) / (N * S))) * (N0**2)

    # Monte Carlo simulation
    total_transmit = 0
    successful_detection = 0
    false_alarm_count = 0

    F = []

    for _ in range(num_iter):
        # Random cyclic delays
        d1, d2 = np.random.randint(1, S, 2)

        # Complex normal channel coefficients
        h1 = np.random.normal(0, np.sqrt(0.5)) + 1j * np.random.normal(0, np.sqrt(0.5))
        h2 = np.random.normal(0, np.sqrt(0.5)) + 1j * np.random.normal(0, np.sqrt(0.5))

        # 50% chance that BS1 will transmit signal
        transmit = np.random.rand() < 0.5

        if transmit:
            total_transmit += 1

            # Generating signals for user 1 and user 2
            x1_n = np.random.randn(S)
            x2_n = np.random.randn(S)

            # Combining signals to produce t1 and t2
            t1_n = a1 * x1_n + a2 * x2_n
            t2_n = a1 * np.roll(x1_n, d1) + a2 * np.roll(x2_n, d2)

            # Rayleigh distributed complex normal noise
            noise_std_dev = N0 * np.sqrt(1 / 2)
            noise = noise_std_dev * (np.random.randn(S) + 1j * np.random.randn(S))

            # Final sent signal
            r_n = h1 * t1_n + h2 * t2_n + noise

            # Cyclic correlation processing
            F_delta1 = np.abs(np.sum(r_n * np.conj(np.roll(r_n, d1)))) / S
            F_delta2 = np.abs(np.sum(r_n * np.conj(np.roll(r_n, d2)))) / S

            F.append({"F1": F_delta1, "F2": F_delta2, "transmit": 1})

            # Decision
            if F_delta1 > lambda_AND and F_delta2 > lambda_AND:
                successful_detection += 1

        if not transmit:
            # Generating noise only
            noise_std_dev = N0 * np.sqrt(1 / 2)
            noise = noise_std_dev * (np.random.randn(S) + 1j * np.random.randn(S))
            r_n = noise

            # Cyclic correlation processing
            F_delta1 = np.abs(np.sum(r_n * np.conj(np.roll(r_n, d1)))) / S
            F_delta2 = np.abs(np.sum(r_n * np.conj(np.roll(r_n, d2)))) / S

            F.append({"F1": F_delta1, "F2": F_delta2, "transmit": 0})

            # Decision
            if F_delta1 > lambda_AND and F_delta2 > lambda_AND:
                false_alarm_count += 1

    # Probability of detection
    Pd = successful_detection / total_transmit if total_transmit > 0 else 0
    Pds.append(Pd)

    # Convert F to DataFrame
    F = pd.DataFrame(F)
    X = F[["F1", "F2"]]
    y = F["transmit"]

    # Normalize the features using StandardScaler
    scaler = StandardScaler()
    X_normalized = scaler.fit_transform(X)

    # Divide the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(
        X_normalized, y, test_size=0.2, random_state=42
    )

    # Classifier
    clf = LogisticRegression(random_state=42, max_iter=1000)

    # Train the Classifier
    clf.fit(X_train, y_train)

    # Define the desired FPR
    desired_fpr = 0.1

    # ROC curve plotting
    y_probs = clf.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_probs)
    roc_auc = auc(fpr, tpr)

    # Create an interpolation function using the FPR and TPR values
    interp_tpr = interp1d(fpr, tpr)

    # Define a new set of FPR values for the interpolated curve
    new_fpr = np.linspace(0, 1, 1000)

    # Use the interpolation function to find the TPR for the new FPR values
    new_tpr = interp_tpr(new_fpr)

    # TPR at desired FPR
    tpr = interp_tpr(desired_fpr)
    TPRs.append(tpr)
    
    print(
        f"SNR: {env_SNR_dB} dB Probability of detection: {Pd} fTPR at {desired_fpr} FPR: {tpr}"
    )
# Out:
# SNR: -25 dB Probability of detection: 0.11187957689178193 fTPR at 0.1 FPR: 0.12133891213389121
# SNR: -24 dB Probability of detection: 0.10501193317422435 fTPR at 0.1 FPR: 0.12003968253968254
# SNR: -23 dB Probability of detection: 0.11799410029498525 fTPR at 0.1 FPR: 0.142570281124498
# SNR: -22 dB Probability of detection: 0.13644524236983843 fTPR at 0.1 FPR: 0.19215686274509805
# SNR: -21 dB Probability of detection: 0.14086193136472466 fTPR at 0.1 FPR: 0.19798994974874373
# SNR: -20 dB Probability of detection: 0.16061760577501505 fTPR at 0.1 FPR: 0.26104023552502453
# SNR: -19 dB Probability of detection: 0.18722466960352424 fTPR at 0.1 FPR: 0.28557013118062563
# SNR: -18 dB Probability of detection: 0.22166899024098785 fTPR at 0.1 FPR: 0.39143426294820716
# SNR: -17 dB Probability of detection: 0.25718221172766625 fTPR at 0.1 FPR: 0.4403578528827038
# SNR: -16 dB Probability of detection: 0.28003166435780724 fTPR at 0.1 FPR: 0.5289499509322866
# SNR: -15 dB Probability of detection: 0.2998800479808077 fTPR at 0.1 FPR: 0.6163021868787276
# SNR: -14 dB Probability of detection: 0.33920615633859863 fTPR at 0.1 FPR: 0.6663286004056795
# SNR: -13 dB Probability of detection: 0.36369131573644975 fTPR at 0.1 FPR: 0.755082284607938
# SNR: -12 dB Probability of detection: 0.4011616262767875 fTPR at 0.1 FPR: 0.8054711246200608
# SNR: -11 dB Probability of detection: 0.43830128205128205 fTPR at 0.1 FPR: 0.8405036726128017
# SNR: -10 dB Probability of detection: 0.49813615852462234 fTPR at 0.1 FPR: 0.8982092365692743
# SNR: -9 dB Probability of detection: 0.5388703011218264 fTPR at 0.1 FPR: 0.9463220675944334
# SNR: -8 dB Probability of detection: 0.5870764381402679 fTPR at 0.1 FPR: 0.9402277039848197
# SNR: -7 dB Probability of detection: 0.6416287803913817 fTPR at 0.1 FPR: 0.9604863221884499
# SNR: -6 dB Probability of detection: 0.6881287726358148 fTPR at 0.1 FPR: 0.9850746268656716
# SNR: -5 dB Probability of detection: 0.7360887096774194 fTPR at 0.1 FPR: 0.9862879529872673
# SNR: -4 dB Probability of detection: 0.7734029730815588 fTPR at 0.1 FPR: 0.979757085020243
# SNR: -3 dB Probability of detection: 0.8322427126710291 fTPR at 0.1 FPR: 0.9911851126346719
# SNR: -2 dB Probability of detection: 0.8611446997178557 fTPR at 0.1 FPR: 0.9940298507462687
# SNR: -1 dB Probability of detection: 0.8871192514433606 fTPR at 0.1 FPR: 0.998992950654582
# SNR: 0 dB Probability of detection: 0.9071343164607414 fTPR at 0.1 FPR: 0.9979959919839679
# SNR: 1 dB Probability of detection: 0.9376618203545111 fTPR at 0.1 FPR: 0.9951267056530214
# SNR: 2 dB Probability of detection: 0.9557734640784471 fTPR at 0.1 FPR: 0.9970238095238095
# SNR: 3 dB Probability of detection: 0.9652448657187994 fTPR at 0.1 FPR: 0.994157740993184
# SNR: 4 dB Probability of detection: 0.9689077326872603 fTPR at 0.1 FPR: 0.9989939637826962
# SNR: 5 dB Probability of detection: 0.9785528161956304 fTPR at 0.1 FPR: 0.998015873015873

# %%
for env_SNR_dB in env_SNRs_dB:
    # Convert SNR from dB to linear scale
    env_SNR_linear = transmitter_power * 10 ** (env_SNR_dB / 10)

    # Noise standard deviation based on environmental SNR
    N0 = np.sqrt(1 / (2 * env_SNR_linear))

    Throughput_without_LR = 0
    Throughput_with_LR = 0

    for i in range(num_iter):
        # Complex normal channel coefficients
        h1 = np.random.normal(0, np.sqrt(0.5)) + 1j * np.random.normal(0, np.sqrt(0.5))
        h2 = np.random.normal(0, np.sqrt(0.5)) + 1j * np.random.normal(0, np.sqrt(0.5))

        Rd = np.log(1 + ((a1 * np.power(np.abs(h1), 2)) / (np.power(N0, 2)))) + np.log(
            1
            + (
                (a2 * np.power(np.abs(h2), 2))
                / (a1 * np.power(np.abs(h2), 2) + np.power(N0, 2))
            )
        )

        Throughput_without_LR += (1 - τ_T) * 0.5 * (1 - Pf) * Rd + 0.5 * Rd * Pds[
            env_SNR_dB + 25
        ]
        Throughput_with_LR += (1 - τ_T) * 0.5 * (1 - Pf) * Rd + 0.5 * Rd * TPRs[
            env_SNR_dB + 25
        ]

    Throughput_without_LR = Throughput_without_LR / num_iter
    Throughput_with_LR = Throughput_with_LR / num_iter

    print("Throughput without LR: ", Throughput_without_LR)
    print("Throughput with LR: ", Throughput_with_LR)
    
    Throughputs_without_LR = np.append(Throughputs_without_LR, Throughput_without_LR)
    Throughputs_with_LR = np.append(Throughputs_with_LR, Throughput_with_LR)
# Out:
# Throughput without LR:  0.003130030572653276
# Throughput with LR:  0.0031595535674245516
# Throughput without LR:  0.003971105544113473
# Throughput with LR:  0.004031021270856358
# Throughput without LR:  0.005038281887476774
# Throughput with LR:  0.005160999876313864
# Throughput without LR:  0.006283680011652614
# Throughput with LR:  0.006624402787847805
# Throughput without LR:  0.007993118435988246
# Throughput with LR:  0.00843564955674862
# Throughput without LR:  0.010353542101473538
# Throughput with LR:  0.011342237915757806
# Throughput without LR:  0.013295728960453754
# Throughput with LR:  0.014508439667676442
# Throughput without LR:  0.0172492395709857
# Throughput with LR:  0.019881039221595533
# Throughput without LR:  0.022137145008698896
# Throughput with LR:  0.025668801995623405
# Throughput without LR:  0.028260505747722174
# Throughput with LR:  0.034267650458287564
# Throughput without LR:  0.03522876009036028
# Throughput with LR:  0.04458919873186258
# Throughput without LR:  0.04555481777100314
# Throughput with LR:  0.05766823734015313
# Throughput without LR:  0.05765556095938946
# Throughput with LR:  0.07564075427482941
# Throughput without LR:  0.07199677802550569
# Throughput with LR:  0.0945241311165411
# Throughput without LR:  0.09300155518506613
# Throughput with LR:  0.12114073501317148
# Throughput without LR:  0.11809302802162161
# Throughput with LR:  0.15210397858704536
# Throughput without LR:  0.1480802206373161
# Throughput with LR:  0.19027673834314676
# Throughput without LR:  0.18583507503049082
# Throughput with LR:  0.23023595328811935
# Throughput without LR:  0.2306628466356638
# Throughput with LR:  0.2786513675372344
# Throughput without LR:  0.2871938325423202
# Throughput with LR:  0.3411989392895564
# Throughput without LR:  0.35054629602681414
# Throughput with LR:  0.40445019044223884
# Throughput without LR:  0.4238901540970314
# Throughput with LR:  0.476444419934649
# Throughput without LR:  0.5103837538244218
# Throughput with LR:  0.5574587352758541
# Throughput without LR:  0.6025438271653227
# Throughput with LR:  0.6482416097097639
# Throughput without LR:  0.7153667002393338
# Throughput with LR:  0.7603753344933881
# Throughput without LR:  0.831411853032808
# Throughput with LR:  0.8734239949094612
# Throughput without LR:  0.9712013280087997
# Throughput with LR:  1.0017208982730115
# Throughput without LR:  1.0903670435715571
# Throughput with LR:  1.114721962073703
# Throughput without LR:  1.2462041740713516
# Throughput with LR:  1.2656150538086024
# Throughput without LR:  1.3937883027569111
# Throughput with LR:  1.4163344948275738
# Throughput without LR:  1.5547495394696205
# Throughput with LR:  1.5709353237736463

# %%
from scipy.signal import savgol_filter

plt.figure()

# Smooth the graph of Pds
Throughputs_with_LR_smooth = savgol_filter(Throughputs_with_LR, window_length=5, polyorder=3)
Throughputs_without_LR_smooth = savgol_filter(Throughputs_without_LR, window_length=5, polyorder=3)

# Plot the smoothed Throughput vs. Environmental SNR
plt.plot(env_SNRs_dB, Throughputs_with_LR_smooth, marker="o", color="red", label="Using ML")
plt.plot(env_SNRs_dB, Throughputs_without_LR_smooth, marker="o", label="Without ML")

plt.title("Throughput vs. Environmental SNR")
plt.xlabel("Environmental SNR (dB)")
plt.ylabel("Throughput at Pf = 0.1 (in bps)")
plt.grid(True)
plt.legend()
plt.show()
